# %% [markdown]
# <a href="https://colab.research.google.com/github/futureDataInfo/transformers/blob/main/SOP_comp_BERT_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers

# %%
! pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.22.1.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from openai) (2.23.0)
# Requirement already satisfied: openpyxl>=3.0.7 in /usr/local/lib/python3.7/dist-packages (from openai) (3.0.10)
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.2.0.62-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 8.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from openai) (4.64.0)
# Collecting openai
#   Downloading openai-0.22.0.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 2.2 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Downloading openai-0.20.0.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 1.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from openai) (1.3.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=3.0.7->openai) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.2.3->openai) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from pandas-stubs>=1.1.0.11->openai) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.3->openai) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->openai) (2022.6.15)
# Building wheels for collected packages: openai
#   Building wheel for openai (PEP 517) ... done
#   Created wheel for openai: filename=openai-0.20.0-py3-none-any.whl size=54118 sha256=f24304f214f01db44c92a5cb8ddbf5a742f20ce74501e0d81f69e9b11932cd3c
#   Stored in directory: /root/.cache/pip/wheels/71/8d/9b/e28529ec53123e0279208f99148d4661232120d78cb866839b
# Successfully built openai
# Installing collected packages: pandas-stubs, openai
# Successfully installed openai-0.20.0 pandas-stubs-1.2.0.62

# %%
 # Open AI initialization
import os
import openai

openai.organization = 'org-B2gFYs6wnA9p7xsz8pREetZM'
openai.api_key = "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"
engine_list = openai.Engine.list()

# %%
# list of questions
QuestionsOld=list(["What do you want to study at this school?",\
"Why you want to study this degree?",\
"Why do you want to study at this particular college/university?",\
"How much experience you have in your field?",\
"Would you like to study or do research under any particular professor? If yes, why only them?",\
"How can you contribute to our university and our program?",\
"What kind of experience you have in your field?",\
"What kind of experience do you want to gain from studying architecture?"])

# %%
TextsOld=list(["Architecture is the will of an epoch translated into space.I was 16 when I first read this quote by Mies van der Rohe, and, back then, I thought I really understood what it meant. Thinking of this quote one summer evening, as I walked around my beloved New York City, I was inspired to commit to a future in architecture. At that early stage, I cherished romantic ideals of designing grandiose buildings that would change a city; of adding my name to the list of architectural geniuses who had immortalized their vision of the world in concrete, steel, glass, and stone. It was in college that I became passionately interested in the theoretical design and engineering concepts that form the basis of architecture, while also exploring in greater detail the sociological and economic impact of architecture.",\
            "The true breakthrough for me took place in my sophomore year of college, when I was volunteering at The Bowery Mission, a women’s shelter situated in Queens, New York. The shelter was in a poorly ventilated building, with an essentially non-functioning air conditioning system. The little bit of relief for the people who stayed there was a small park nearby, a patch of green between suffocating buildings. One day when I was working the afternoon shift there in the peak of summer, I looked out to see bulldozers in the park. It was being torn up to make room for yet another building. I saw that completed building a year later – a grey block of steel that did not utilize any of the original park space. Witnessing this injustice, while learning every day about how climatology, materials technology, and engineering mechanics intersect with urban planning and architectural design, ignited a passion for sustainable design in me. [BeMo2] How can we, as architects, minimize our harm to communities and eco-systems? How can we design buildings with a view to sustain long-term energy and resource efficiency without sacrificing immediate economic viability? What are the eco-conscious solutions that architects can put forward to address the environmental changes of the 21st century? These were the questions that plagued me then and I have pursued the answers to these questions throughout my academic career so far.",\
            "I found the answers to some of these questions in the robust curriculum I pursued at ABC College of Architecture, New York. I took up advanced coursework in Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which helped me hone my technical skills. As my interest in sustainable architecture developed, I became curious about the social and anthropological impact of architecture. I studied Art History, African American Literature, Anthropology, and Cultures of Ancient Greece, which helped me develop a deeper understanding of the socio-ecological impact of architecture and ethical responsibilities of architects. With this strong background of academic exploration, my architectural philosophy continued to evolve. I became interested in cutting-edge design techniques and their application to sustainable design. In my junior year at college, I participated in the New Dimensions of Architecture conference held in New York City, presenting my own paper on “Analyzing the Implications of the Weiszman Design Theory for the Sustainable Architecture of the Future”. In fact, it was at this conference that I met Professor Richard Wright, the esteemed architect and professor emeritus at the Architecture department of XYZ University. Talking with him was one of the most enlightening moments of my life. We discussed our shared passion for ecologically efficient and socially cohesive architectural solutions, and he introduced me to the works of Leonard Nieman, Mary Andrews, and other cutting-edge green architecture firms that are making a real contribution to ecologically sustainable urban planning.",\
            "In fact, the possibility of learning from and working directly with Professor Wright is one of my main reasons to seek admission into your M.Arch program. His innovative design theories have a tremendous potential for sustainable architecture solutions. I would love to learn from him and collaborate with him to continue to explore my interest in these topics. I am also deeply interested in the scope of studies afforded by your wide-ranging curriculum that focuses on the latest architectural innovations as well as socio-economic evolutions in architecture. Moreover, for a budding green architect, nothing is more attractive than your quarterly line-up of seminars and conferences that frequently feature the names of the architects at the forefront of design innovation. With my strong academic background in both the technical and socio-economic aspects of architecture, and my focused passion on sustainable architectural solutions for the future, I think I am a perfect candidate for your master’s program. ",\
            "This education is exactly what I need to launch me into the next phase of my career, where I hope to gain experience at one of New York’s top green architecture firms, working on problems of low-budget housing, eco-friendly factory designs, and organic city planning. Eventually, I hope to specialize in sustainable, low-budget urban planning for socio-economically disadvantaged neighborhoods.It’s funny to think how far I’ve come from my early romanticized ideals of what it meant to be an architect. Those sunset walks around New York city from my teenage years, surrounded by the works of Mies van der Rohe and Rem Koolhas, inspired in me an awe for the cultural power an architect can wield. It was an early lesson that a building can both represent and transform spaces. Today when I walk around my beloved city, what I see are the innumerable missed architectural opportunities to organically inhabit and improve any given space with sustainable design. And now, when I consider Mies van der Rohe’s famous quote, I no longer think of my own petty will or the limited scope of individual genius; I think of the will of an entire generation committed to saving our planet with team-work, collaboration, and true passion, and how grateful I am to be a part of this generation of architects."])

# %%
def OpenAI_QA(question,text):
  response = openai.Completion.create(
  model="text-curie-001",
  prompt=text+"\n\nQuestions:n1."+question+"\n\n\nAnswers:\n\n",
  temperature=0.1,
  max_tokens=400,
  top_p=1,
  frequency_penalty=0.37,
  presence_penalty=0,
  stop=["\n\n"])
  return response["choices"][0]["text"]

# %%
# list of questions
QuestionsFirst=list(["What do you want to study at this school?",\
"Why you want to study this degree?",\
"Why do you want to study at this particular college/university?",\
"How much experience you have in your field?",\
"Would you like to study or do research under any particular professor? If yes, why only them?",\
"How can you contribute to our university and our program?",\
"What have you done in the field of architecture?",\
"What are your reasons for studying architecture in this university?"])

# %%
# list of questions
Questions=list(["curriculum study at this school",\
"reasons for studying the program",\
"reasons for studying at this particular college/university?",\
"experience you have in your field",\
"preference for any particular professor and why",\
"adding value to our university and our program while studying there",\
"previous experiences in thwe field",\
"fguture contribution you want to make in the field"])

# %%
from transformers import BertTokenizer, BertForQuestionAnswering
import torch

tokenizer = BertTokenizer.from_pretrained("deepset/bert-base-cased-squad2")
model = BertForQuestionAnswering.from_pretrained("deepset/bert-base-cased-squad2")
# Out:
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/152 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/413M [00:00<?, ?B/s]

# %%
def BERT_QA(q,t):
   inputs = tokenizer(q,t, return_tensors="pt")

   with torch.no_grad():
      outputs = model(**inputs)

   answer_start_index = outputs.start_logits.argmax()
   answer_end_index = outputs.end_logits.argmax()

   predict_answer_tokens = inputs.input_ids[0,answer_start_index : answer_end_index + 1]
   return tokenizer.decode(predict_answer_tokens)

# %%
import os
import pandas as pd
import glob
import nltk
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Mounted at /content/gdrive

# %%
def analyze(text,outfile):
#question, text = "Who was Jim Henson?", "Jim Henson was a nice puppet"
  sentences = sent_tokenize(text)
  Texts=[]
  tempStr=''
  for s in sentences:
    if ((len(tempStr) + len(s) < 400)):
      tempStr=tempStr + s
    else:
      Texts.append(tempStr)
      tempStr=''  

  question_num=0
  outfile.write(text+'/n')

  while (question_num < len(Questions)):
    print("\n\n\nquestion==============================")
    print(Questions[question_num])
    outfile.write("\n\nquestion=============================="+'/n')
    outfile.write(Questions[question_num])
    print("\nBERT ANSWER===========================")
    outfile.write("\nBERT ANSWER===========================")
    
    text_num=0
    while (text_num < len(Texts)):
      b_answer=BERT_QA(Questions[question_num],Texts[text_num])
      if (b_answer != '[CLS]'):
        print(b_answer)
        outfile.write(b_answer)
      text_num=text_num+1

    print("\nOPenAI ANSWER=====================")
    outfile.write("\nOpenAI ANSWER===========================")
    a_answer=OpenAI_QA(Questions[question_num],text)
    outfile.write(a_answer)
    print(a_answer)
    question_num=question_num+1

# %%
#os.chdir("/content/gdrive/MyDrive/FutureDataWork/sop/sop_sample")
path = "/content/gdrive/MyDrive/FutureDataWork/sop/sop_sample"
#savepath = os.getcwd()
for f in glob.glob(path +"/*.txt"):
    print(f)
    infile = open(f)
    outpath=f[0:len(f)-4]+'analysis.txt.2'
    print(outpath)
    outfile = open(outpath,'a')
    sop = infile.read()
    analyze(sop,outfile)
    infile.close()
    #break;
    outfile.close
# Out:
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample2.txt
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample2analysis.txt.2
#
#
#
# question==============================
# curriculum study at this school
#
# BERT ANSWER===========================
# clinical psychology
# after - school care program for children and teens from disadvantaged backgrounds.
# Clinical Psychology
# Peer Youth Counselling certificate course from the Ryerson Center for Mental Health.
# Biology, Physiology, and Neuroscience
# Guntherson Memorial Lab at ABC University, on their studies into the development of substance abuse in adolescents suffering from PTSD.
#
#
#
# OPenAI ANSWER=====================
#
# 1. Yes, this student has studied curriculum at this school.
#
#
#
# question==============================
# reasons for studying the program
#
# BERT ANSWER===========================
# Our parents
# pursuing clinical psychology as a career
# after - school care program for children and teens from disadvantaged backgrounds
# my personal and first - hand experiences with the effects of trauma, I think I can bring a unique perspective to the study of long - term PTSD in adolescents.
# Peer Youth Counselling certificate course from the Ryerson Center for Mental Health.
# to better understand the physical pathologies of adolescent trauma. I believe this thorough grounding in the biological aspects of developmental psychopathology will help me to address the sorely needed requirement for cross - disciplinary research into effective treatment programs for trauma survivors.
# suffering from PTSD.
# valuable observational and data analysis skills and learn more about critical aspects of clinical research such as programming computer tests, investigating study measures, forming hypotheses, supervising participants, and more.
# my interest in the questions of trauma, anxiety, and depression continue to be deeply personal.
#
# OPenAI ANSWER=====================
#
# 1. To gain a better understanding of the effects of trauma on the development of generalized anxiety disorders and panic disorders in adolescents.
# 2. To develop the skills and knowledge needed for conducting clinical research in this area.
# 3. To contribute to the growing body of knowledge about effective treatment programs for trauma survivors.
#
#
#
# question==============================
# reasons for studying at this particular college/university?
#
# BERT ANSWER===========================
# Our parents did not really understand the impact of what she was going through and as a family, we never talked about it much, though we all could witness her pain. So, through my teen years, I watched as a beloved family member struggled with her mental health.
# challenging experience set me on the path to pursuing clinical psychology
# long - term effects of those early experiences.
#
# Intro to Psychology classes
# to better understand the physical pathologies
# suffering from PTSD.
# [CLS] reasons for studying at this particular college / university? [SEP] Thanks to this experience, I was able to develop my valuable observational and data analysis skills and learn more about critical aspects of clinical research such as programming computer tests, investigating study measures, forming hypotheses, supervising participants, and more.
# my interest in the questions of trauma, anxiety, and depression continue to be deeply personal.
#
# OPenAI ANSWER=====================
#
# 1. I am interested in pursuing a Ph.D. in Clinical Psychology, and I believe this is the best place to do so.
#
#
#
# question==============================
# experience you have in your field
#
# BERT ANSWER===========================
# Clinical Psychology
# Intro to Psychology
# Biology, Physiology, and Neuroscience to better understand the physical pathologies of adolescent trauma. I believe this thorough grounding in the biological aspects of developmental psychopathology
# [CLS] experience you have in your field [SEP] For my last two years of undergrad, I worked with Drs. Rebecca Brown, Tyler Baker, and Gary Wolf at the Guntherson Memorial Lab at ABC University, on their studies into the development of substance abuse in adolescents suffering from PTSD
#
# OPenAI ANSWER=====================
#
# 1. I have experience working with adolescents who have experienced trauma, as well as experience conducting research. This has given me a deep understanding of the effects of trauma on the development of mental health problems in adolescents.
# 2. I have a strong interest in the questions of how trauma can warp an adolescent brain and what we can do to try and manage it. This is why I am pursuing a Ph.D in Clinical Psychology.
#
#
#
# question==============================
# preference for any particular professor and why
#
# BERT ANSWER===========================
# clinical psychology
#
# OPenAI ANSWER=====================
#
# I have a preference for Dr. Rebecca Brown as my professor because she is an expert in the area of adolescent trauma and has published extensively on the topic. Her research is highly respected and I believe her class will provide me with the critical research skills necessary to pursue a Ph.D. in Clinical Psychology.
#
#
#
# question==============================
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
# clinical psychology
#
# [CLS] adding value to our university and our program while studying there [SEP] While in high school, I took up Intro to Psychology classes from my local community college and completed a Peer Youth Counselling certificate course from the Ryerson Center for Mental Health
# to better understand the physical pathologies of adolescent trauma. I believe this thorough grounding in the biological aspects of developmental psychopathology
# ABC University
# clinical experiences and academic knowledge I gained in the last few years, my interest in the questions of trauma, anxiety, and depression continue to be deeply personal.
#
# OPenAI ANSWER=====================
#
# 1. Adding value to our university and our program while studying there would include conducting original research, publishing scholarly work, and being a contributing member of the community.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
#
# clinical psychology
#
# Clinical Psychology
# Intro to Psychology
# Biology, Physiology, and Neuroscience
# Drs. Rebecca Brown, Tyler Baker, and Gary Wolf at the Guntherson Memorial Lab at ABC University, on their studies into the development of substance abuse in adolescents suffering from PTSD.
# clinical research
#
#
# OPenAI ANSWER=====================
#
# 1. I have previous experience working with adolescents, specifically those who have experienced trauma. This includes working with children and teens who have experienced starvation, neglect, abuse, and violence. Through my work with these kids, I have gained a deep understanding of how trauma can impact the development of generalized anxiety disorders and panic disorders in adolescents.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# I wanted to question, dissect, analyze, and hopefully, understand, this mysterious phenomenon that had dominated my life for so long.
#
# Master ’ s student in the Clinical Psychology program of your university. Thanks to my personal and first - hand experiences with the effects of trauma, I think I can bring a unique perspective to the study of long - term PTSD in adolescents
# Peer Youth Counselling
# thorough grounding in the biological aspects of developmental psychopathology will help me to address the sorely needed requirement for cross - disciplinary research
# their studies into the development of substance abuse in adolescents suffering from PTSD.
# [CLS] fguture contribution you want to make in the field [SEP] Thanks to this experience, I was able to develop my valuable observational and data analysis skills and learn more about critical aspects of clinical research
#
# OPenAI ANSWER=====================
#
# I hope to contribute to the field of clinical psychology by studying the effects of trauma on the development of generalized anxiety disorders and panic disorders in adolescents, and by exploring the need for cross-disciplinary research into effective treatment programs for trauma survivors.
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample3.txt
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample3analysis.txt.2
#
#
#
# question==============================
# curriculum study at this school
#
# BERT ANSWER===========================
# “ Third World Development
# undergraduate research was dedicated to understanding the ways and means of political participation for women in remote Northeast India.
#
# social capital, defined in this case as a public good comprised of relationships and networks, in leading to better health outcomes amongst highly - marginalized urban women.
# connectedness for women on the periphery.
#
# schools
# maternal social networks, neighborhood environments, and the transmission of eating behaviors to children. In effect, my role would be to help operationalize maternal adversity
#
# School of Kinesiology and Health Studies is an excellent institution that is well - equipped to support new graduate students interested in innovative ways to explore social challenges
# research assistant on a larger project studying large, linked quantitative databases of provincial health and corrections data in my home state.
#
# OPenAI ANSWER=====================
#
#
#
#
# question==============================
# reasons for studying the program
#
# BERT ANSWER===========================
# rather radical and lively professors from Trinidad, Chile, and Lebanon, respectively. This course, despite its passé title, existed to deconstruct our notions of ‘ otherness ’ by illustrating the deep connectedness of issues, people, and nations.
# understanding the ways and means of political participation for women in remote Northeast India. I became curious about the role of women as informal politicians within their small collectives where survival literally hinges on connectivity.
# lobby local governments
# social capital, defined in this case as a public good comprised of relationships and networks, in leading to better health outcomes amongst highly - marginalized urban women
# connectedness for women on the periphery.
# the centrality of connectedness, to institutions and peers, to the processes that enable an individual to access, choose, and influence. My current work as a policy analyst with the Public Health Agency within the Strategic Initiatives and Innovations Directorate is focused largely on reducing health inequalities by mobilizing action on particular social determinants of health.
# health can be positively affected
# potentially causal nexus between maternal social networks, neighborhood environments, and the transmission of eating behaviors to children
# I am attracted to the study of populations that are not necessarily bound by their geography but by common circumstances
# support new graduate students interested in innovative ways to explore social challenges.
# research assistant on a larger project studying large, linked quantitative databases of provincial health and corrections data in my home state.
#
# OPenAI ANSWER=====================
#
# 1. I am interested in studying the social mechanisms by which parental social connections impact the eating behavior of their children as well as the way in which these mechanisms may vary across local neighborhoods.
# 2. I am drawn to the School of Kinesiology and Health Studies specifically due to Dr. Spencer Moore’s background in medical anthropology and current work with social network analytic techniques.
# 3. Social network analysis is a fascinating way of quantifying social capital and social networks and I am very enthusiastic about the opportunity to study these methods and methodologies under Dr. Moore.
#
#
#
# question==============================
# reasons for studying at this particular college/university?
#
# BERT ANSWER===========================
# rather radical and lively professors from Trinidad, Chile, and Lebanon, respectively. This course, despite its passé title, existed to deconstruct our notions of ‘ otherness ’ by illustrating the deep connectedness of issues, people, and nations.
# survival literally hinges on connectivity.
# public health approaches to vulnerable populations
# social capital, defined in this case as a public good comprised of relationships and networks, in leading to better health outcomes amongst highly - marginalized urban women
# connectedness for women on the periphery.
# [CLS] reasons for studying at this particular college / university? [SEP] My particular interest is the potentially causal nexus between maternal social networks, neighborhood environments, and the transmission of eating behaviors to children
# [CLS] reasons for studying at this particular college / university? [SEP] The application of network theory analytical techniques will be a new endeavor for me, but I am attracted to the study of populations that are not necessarily bound by their geography but by common circumstances
# to support new graduate students interested in innovative ways to explore social challenges
# grounded theory and warranted assertion analysis techniques common to sociological research
#
# OPenAI ANSWER=====================
#
# 1. I am drawn to the School of Kinesiology and Health Studies specifically due to Dr. Spencer Moore’s background in medical anthropology and current work with social network analytic techniques. The application of network theory analytical techniques will be a new endeavor for me, but I am attracted to the study of populations that are not necessarily bound by their geography but by common circumstances, such as maternal adversity, and, potentially, common health effects related to obesity and food behaviors.
#
#
#
# question==============================
# experience you have in your field
#
# BERT ANSWER===========================
# understanding the ways and means of political participation for women in remote Northeast India. I became curious about the role of women as informal politicians within their small collectives where survival literally hinges on connectivity
# public health
# health can be positively affected
#
# OPenAI ANSWER=====================
#
# 1. I have experience in my field as a research assistant on a larger project studying large, linked quantitative databases of provincial health and corrections data in my home state. I also have a sufficient course work history in statistics and epidemiology to be able to make the leap to more advanced quantitative techniques, given access to graduate courses on the subject.
#
#
#
# question==============================
# preference for any particular professor and why
#
# BERT ANSWER===========================
# radical and lively
#
# OPenAI ANSWER=====================
#
# 1. I have a strong preference for Dr. Moore because of his background in medical anthropology and current work with social network analytic techniques. This will be a new endeavor for me, but I am very excited about the opportunity to study this method and methodology under him.
# 2. I prefer professors who are well-equipped to support new graduate students interested in innovative ways to explore social challenges, and Dr. Moore is definitely that type of professor.
#
#
#
# question==============================
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
# by illustrating the deep connectedness of issues, people, and nations.
#
# public health approaches to vulnerable populations
# social capital, defined in this case as a public good comprised of relationships and networks, in leading to better health outcomes amongst highly - marginalized urban women.
# how health outcomes can be a partial function of connectedness for women on the periphery.
# research assistant on a larger project studying large, linked quantitative databases of provincial health and corrections data in my home state.
#
# OPenAI ANSWER=====================
#
# 1. I would like to add value to my university and my program by conducting research that is innovative, relevant, and impactful.
# 2. I am interested in studying social networks as enablers of obesity and food behavior outcomes among marginalized women and their young children.
# 3. I have experience as a research assistant on a larger project studying large, linked quantitative databases of provincial health and corrections data in my home state. I also have a sufficient course work history in statistics and epidemiology to be able to make the leap to more advanced quantitative techniques, given access to graduate courses on the subject.
# 4. Social network analysis is a fascinating way of quantifying social capital and social networks and I am very enthusiastic about the opportunity to study these methods and methodologies under Dr. Moore.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
# professors from Trinidad, Chile, and Lebanon
# remote Northeast India. I became curious about the role of women as informal politicians within their small collectives
# public health approaches to vulnerable populations
# highly - marginalized urban women
# health outcomes can be a partial function of connectedness for women on the periphery.
# [CLS] previous experiences in thwe field [SEP] I see the centrality of connectedness, to institutions and peers, to the processes that enable an individual to access, choose, and influence. My current work as a policy analyst with the Public Health Agency within the Strategic Initiatives and Innovations Directorate
# families, neighborhoods, schools, communities
# maternal social networks, neighborhood environments, and the transmission of eating behaviors to children
# application of network theory analytical techniques
# Kinesiology and Health Studies is an excellent institution that is well - equipped to support new graduate students interested in innovative ways to explore social challenges
# qualitative in nature
#
# OPenAI ANSWER=====================
#
# 1. I have previous experience conducting qualitative research, which relies on grounded theory and warranted assertion analysis techniques.
# 2. I am interested in studying the social mechanisms by which parental social connections impact the eating behavior of their children, and am particularly interested in the potentially causal nexus between maternal social networks, neighborhood environments, and the transmission of eating behaviors to children.
# 3. I am drawn to the School of Kinesiology and Health Studies specifically due to Dr. Moore’s background in medical anthropology and current work with social network analytic techniques. The application of network theory analytical techniques will be a new endeavor for me, but I am attracted to the study of populations that are not necessarily bound by their geography but by common circumstances, such as maternal adversity, and, potentially, common health effects related to obesity and food behaviors.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# [CLS] fguture contribution you want to make in the field [SEP] During the first year of my undergraduate degree, I took a small course entitled “ Third World Development ” taught by three rather radical and lively professors from Trinidad, Chile, and Lebanon, respectively. This course, despite its passé title, existed to deconstruct our notions of ‘ otherness ’ by illustrating the deep connectedness of issues, people, and nations.
# understanding the ways and means of political participation
# lobby local governments and participate legitimately in the polity
# [CLS] fguture contribution you want to make in the field [SEP] My research led to my questions about the role of social capital, defined in this case as a public good comprised of relationships and networks, in leading to better health outcomes amongst highly - marginalized urban women
# [CLS] fguture contribution you want to make in the field [SEP] I see the centrality of connectedness, to institutions and peers, to the processes that enable an individual to access, choose, and influence. My current work as a policy analyst with the Public Health Agency within the Strategic Initiatives and Innovations Directorate is focused largely on reducing health inequalities by mobilizing action on particular social determinants of health.
# enablers, including social networks as a form of social capital, are sometimes lumped, and incorrectly so, with the more tangible determinants, such as housing and nutrition. I see these enablers as characteristics of favorable environments in which health can be positively affected
# help operationalize maternal adversity and identify potential moderators on the effects of maternal adversity on obesity and eating behaviors of children.
#
# support new graduate students
# [CLS] fguture contribution you want to make in the field [SEP] My prior individual research experiences were qualitative in nature, relying on grounded theory and warranted assertion analysis techniques common to sociological research
#
# OPenAI ANSWER=====================
#
# I am interested in using social network analysis to understand the role of social capital in obesity and food behaviors outcomes among marginalized women and their young children. I believe that this is an important area of research that has yet to be fully explored, and that network analysis can provide a more nuanced and detailed understanding of how social networks play a role in health outcomes.
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample4.txt
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample4analysis.txt.2
#
#
#
# question==============================
# curriculum study at this school
#
# BERT ANSWER===========================
# an erasure of not only their personal history but the history of generations who came before them
# first history project
# social, cultural, military, and economic history of south - east Asia.
# how oral traditions develop to combat lack of literacy
# [CLS] curriculum study at this school [SEP] I credit a wide range of authors, thinkers, and historians with molding my interests and refining my analysis. The latest papers by BW Anandya, Wazir Jahan Karim, and N Choi about the pathways to religious and political power for women in southeast Asia, profoundly opened up my mind to the possibilities for what we can learn from primary resources about these “ lost ” populations of history
# [CLS] curriculum study at this school [SEP] I have always followed my intellectual curiosity to take on challenging coursework and build a solid academic foundation for my intended pursuit of historical research
# independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures.
#
# University of Mumbai
# ABC University
# PhD candidate, I would love to get the chance to tap into ABC University
# master ’ s program
#
# OPenAI ANSWER=====================
#
# 1. The curriculum at this school encourages diversity, forward-thinking research, and cutting-edge investigative techniques.
# 2. The curriculum at this school helps students refine their understanding of historical investigation methods and expand their consciousness of the cross-cultural socio-economic influences in pre-modern women’s spaces.
# 3. The curriculum at this school encourages students to pursue a PhD from this school.
#
#
#
# question==============================
# reasons for studying the program
#
# BERT ANSWER===========================
# I was always attracted to the hidden facts behind the grand narratives of history ; the little stories of small people who didn ’ t leave an impact on major world events but lived, breathed, and worshipped just the same.
# an erasure of not only their personal history but the history of generations who came before them. As I grew up, I became passionately interested in the history of my ancestors, perhaps as a way of making sense of my own experiences as a second - generation immigrant.
# it was a traumatic reminder of all she had lost. I consider this genealogical tree my first history project
# fueled a passion in me for finding out all about where I had come from,
# how oral traditions develop to combat lack of literacy
# credit a wide range of authors, thinkers, and historians with molding my interests and refining my analysis. The latest papers by BW Anandya, Wazir Jahan Karim, and N Choi about the pathways to religious and political power for women in southeast Asia, profoundly opened up my mind to the possibilities for what we can learn from primary resources about these “ lost ” populations of history.
# intellectual curiosity to take on challenging coursework and build a solid academic foundation for my intended pursuit of historical research.
# independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures.
# Annual National History Symposium in X year.
# I got the chance to work on my main area of interest while using primary resources on loan from University of Mumbai,
# my personal background, academic proficiency, and focused historical interests, I think I represent an ideal candidate for ABC University. I look forward to working in an environment that encourages diversity, forward - thinking research, and cutting - edge investigative techniques.
#
# encouragement and support
#
# OPenAI ANSWER=====================
#
# 1. I am interested in the history of south-east Asia and the politics of historical interpretation, especially in regard to women in pre-modern south-east Asia.
# 2. I credit a wide range of authors, thinkers, and historians with molding my interests and refining my analysis.
# 3. The latest papers by BW Anandya, Wazir Jahan Karim, and N Choi about the pathways to religious and political power for women in southeast Asia, profoundly opened up my mind to the possibilities for what we can learn from primary resources about these “lost” populations of history.
# 4. On the other hand, the philosophical and sociological theories of Edward Said, Gayatri Chakrovorti Spivak, and Homi Bhabha provide the philosophical framework for how I approach my writing.
# 5. I have always followed my intellectual curiosity to take on challenging coursework and build a solid academic foundation for my intended pursuit of historical research. Apart from completing the most intensive coursework pertaining to Asian history studies in my department, I also took courses in British History, Postcolonialism, Anthropology, Philosophy, and Women’s Studies, so as to round out my understanding of the key topics related to my area of interest.
# 6. My professor also allowed me to complete independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures. The study of such diverse historical topics helped to provide greater context to my primary area of interest; I found many interesting parallels between the experiences of oppressed populations in different parts of the world.
# 7. Three of my papers were published in our university’s academic magazine, and I presented my paper on “Development of Oral Traditions in Women’s Spaces” at the Annual National History Symposium in X year.
# 8. In my junior year, I got the chance to write an independent research paper about the historical figure
#
#
#
# question==============================
# reasons for studying at this particular college/university?
#
# BERT ANSWER===========================
# fled from war, famine, death, and other horrors I myself have never had to face,
# making sense of my own experiences as a second - generation immigrant.
# it was a traumatic reminder of all she had lost. I consider this genealogical tree my first history project
# fueled a passion in me for finding out all about where I had come from,
# lack of literacy
# [CLS] reasons for studying at this particular college / university? [SEP] I credit a wide range of authors, thinkers, and historians with molding my interests and refining my analysis. The latest papers by BW Anandya, Wazir Jahan Karim, and N Choi about the pathways to religious and political power for women in southeast Asia, profoundly opened up my mind to the possibilities for what we can learn from primary resources about these “ lost ” populations of history.
# to take on challenging coursework
# independent studies and research projects
# a major milestone for me as I got the chance to work on my main area of interest while using primary resources on loan from University of Mumbai
# academic proficiency, and focused historical interests
# trailbreakers
# encouragement and support
#
# OPenAI ANSWER=====================
#
# 1. I am interested in pursuing a PhD at a top university such as ABC University, and your rigorous curriculum will help me refine my understanding of historical investigation methods and expand my consciousness of the cross-cultural socio-economic influences in pre-modern women’s spaces.
#
#
#
# question==============================
# experience you have in your field
#
# BERT ANSWER===========================
# first history project
# [CLS] experience you have in your field [SEP] But it fueled a passion in me for finding out all about where I had come from,
# [CLS] experience you have in your field [SEP] The history of women ’ s spaces, especially under patriarchal regimes, fascinates me ; how oral traditions develop to combat lack of literacy
# [CLS] experience you have in your field [SEP] I have always followed my intellectual curiosity to take on challenging coursework and build a solid academic foundation for my intended pursuit of historical research
# African American history in Canada and History of Hebrew Scriptures.
# Annual National History Symposium in X year.
# I got the chance to work on my main area of interest while using primary resources on loan from University of Mumbai,
#
#
# OPenAI ANSWER=====================
#
# I have a background in history with a minor in anthropology, and I have been pursuing my academic interests in south-east Asia by completing intensive coursework related to Asian history studies in my department. I also took courses in British History, Postcolonialism, Anthropology, Philosophy, and Women’s Studies, so as to round out my understanding of the key topics related to my area of interest. My professor also allowed me to complete independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures. The study of such diverse historical topics helped to provide greater context to my primary area of interest; I found many interesting parallels between the experiences of oppressed populations in different parts of the world. Three of my papers were published in our university’s academic magazine, and I presented my paper on “Development of Oral Traditions in Women’s Spaces” at the Annual National History Symposium in X year.
#
#
#
# question==============================
# preference for any particular professor and why
#
# BERT ANSWER===========================
# [CLS] preference for any particular professor and why [SEP] It was an erasure of not only their personal history
# [CLS] preference for any particular professor and why [SEP] My mother started crying when I asked her for these details and photos ; it was a traumatic reminder of all she had lost. I consider this genealogical tree my first history project
#
# OPenAI ANSWER=====================
#
# 1. I have a preference for Dr. Nina Gupta, as she is an expert in the field of Southeast Asian women’s studies and her research has directly impacted my own interests. I am excited to learn from her and build on our mutual understanding of the subject matter.
#
#
#
# question==============================
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
#
# my first history project
# passion in me for finding out all about where I had come from,
# how oral traditions develop to combat lack of literacy
# opened up my mind to the possibilities for what we can learn from primary resources about these “ lost ” populations of history
# academic foundation for my intended pursuit of historical research
# independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures
# University of Mumbai
# ABC University. I look forward to working in an environment that encourages diversity
# ABC University
# [CLS] adding value to our university and our program while studying there [SEP] In fact, her encouragement and support motivated me to apply to your master ’ s program! My next big goal is to pursue a PhD, also from your university, under Nina Gupta ’ s supervision. Through my master ’ s education, I plan to work towards developing my expertise in Southeast Asian women ’ s studies and making myself an asset for your PhD program
#
# OPenAI ANSWER=====================
#
# 1. I would love to contribute to ABC University in a number of ways, such as providing value-added research, teaching students, and serving on committees and boards.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
# a child of Bangladeshi refugees
# second - generation immigrant.
# it was a traumatic reminder of all she had lost. I consider this genealogical tree my first history project,
# But it fueled a passion in me for finding out all about where I had come from, and from there, I developed my interest in the social, cultural, military, and economic history of south - east Asia.
# how these historical changes constitute the present.
# BW Anandya, Wazir Jahan Karim, and N Choi about the pathways to religious and political power for women in southeast Asia, profoundly opened up my mind to the possibilities for what we can learn from primary resources about these “ lost ” populations of history
# historical research
# African American history in Canada and History of Hebrew Scriptures
# National History Symposium in X year.
# University of Mumbai, including Savitri Bai Phule ’ s journals, historical Times of India
# academic proficiency, and focused historical interests
# Dr. Nina Gupta from the History of Southeast Asia department
#
#
# OPenAI ANSWER=====================
#
# 1. I have always been interested in the history of south-east Asia, and my previous experiences in the field have helped me to develop a strong foundation for my intended pursuit of historical research. In addition to completing the most intensive coursework related to Asian history studies in my department, I also took courses in British History, Postcolonialism, Anthropology, Philosophy, and Women’s Studies, so as to round out my understanding of the key topics related to my area of interest. My professor also allowed me to complete independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures. The study of such diverse historical topics helped to provide greater context to my primary area of interest; I found many interesting parallels between the experiences of oppressed populations in different parts of the world. Three of my papers were published in our university’s academic magazine, and I presented my paper on “Development of Oral Traditions in Women’s Spaces” at the Annual National History Symposium in X year.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# [CLS] fguture contribution you want to make in the field [SEP] It was an erasure of not only their personal history but the history of generations who came before them. As I grew up, I became passionately interested in the history of my ancestors, perhaps as a way of making sense of my own experiences as a second - generation immigrant.
# first history project
# it fueled a passion in me for finding out all about where I had come from,
# [CLS] fguture contribution you want to make in the field [SEP] I credit a wide range of authors, thinkers, and historians with molding my interests and refining my analysis
# [CLS] fguture contribution you want to make in the field [SEP] I have always followed my intellectual curiosity to take on challenging coursework and build a solid academic foundation for my intended pursuit of historical research.
# [CLS] fguture contribution you want to make in the field [SEP] My professor also allowed me to complete independent studies and research projects in selected areas of my interest such as African American history in Canada and History of Hebrew Scriptures.
# [CLS] fguture contribution you want to make in the field [SEP] Three of my papers were published in our university ’ s academic magazine, and I presented my paper on “ Development of Oral Traditions in Women ’ s Spaces
# my main area of interest
# diversity
# I would love to get the chance to tap into ABC University ’ s extensive network of primary resources, subject matter experts, and trailbreakers
# I plan to work towards developing my expertise in Southeast Asian women ’ s studies and making myself an asset for your PhD program.
#
# OPenAI ANSWER=====================
#
# I want to contribute to the field of history by researching and writing about the history of women in south-east Asia, specifically under colonial influences. I believe that by doing so, I can provide a more nuanced and accurate understanding of these populations' experiences, and help to dispel the myths and misconceptions that abound in popular culture. Additionally, I hope to develop a strong foundation in historical research methods, so that I can conduct my own investigations with confidence and accuracy.
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample5.txt
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample5analysis.txt.2
#
#
#
# question==============================
# curriculum study at this school
#
# BERT ANSWER===========================
# my mother ’ s clerking post at the American consulate in Cairo
# complexity of being a light - skinned American kid wandering through these halls
# cultural and political analysis expanded as I got older and began to unpack the complicated colonial forces that played a part in both early and contemporary Egyptology
# international exhibition
# undergraduate university
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# Presidential Internship program
# PhD program in anthropology
#
# independent scholarship and teaching
#
# OPenAI ANSWER=====================
#
# Anthropology
#
#
#
# question==============================
# reasons for studying the program
#
# BERT ANSWER===========================
# my mother ’ s clerking post at the American consulate in Cairo provided us with an immense array of benefits
# complexity of being a light - skinned American kid wandering through these halls,
# abstract uneasiness in my head.
# overwhelmed by how drastically the Egyptian archaeological " industry " had been shaped by British colonialism, and how this resulted in a still - developing tension between international exhibition and the local or indigenous preservation of civilizational artifacts.
# better support repatriation efforts
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# American University in Cairo ’ s Presidential Internship program
# personal experience.
# support a more culturally - focused analysis
# I would not only seek to contribute to the program's ongoing scholarship as a student, but would hope to continue working collaboratively with the department once I move into independent scholarship and teaching following graduation.
#
# OPenAI ANSWER=====================
#
# 1. I am interested in studying the program because it offers a unique perspective on how anthropology, political science, and archaeology intersect in Egyptological studies.
# 2. I feel that this program will provide me with the skills and knowledge to be a productive and prominent member of the department's research cohort.
#
#
#
# question==============================
# reasons for studying at this particular college/university?
#
# BERT ANSWER===========================
# benefits
# complexity
# abstract uneasiness in my head.
# international exhibition and the local or indigenous preservation of civilizational artifacts.
# repatriation efforts
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# American University in Cairo ’ s Presidential Internship program in 2019, just after graduating. Returning to Cairo for the first time since I was 13 years old was incredible but bittersweet in some ways.
# personal experience
# independent scholarship and teaching following graduation.
#
# OPenAI ANSWER=====================
#
# 1. I chose this college/university because of its strong focus on interdisciplinary research and its commitment to providing opportunities for students to engage with the wider world.
#
#
#
# question==============================
# experience you have in your field
#
# BERT ANSWER===========================
# cultural and political analysis expanded as I got older and began to unpack the complicated colonial forces that played a part in both early and contemporary Egyptology
#
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# Presidential Internship program
#
# OPenAI ANSWER=====================
#
# 1. I have experience in my field as an undergraduate student, working with Professor X on research related to artifact repatriation and return from the British Museum.
# 2. I have experience in my field as a graduate student, working with Professor Z on research related to contemporary cultural discourse in Egyptian and Islamic political movements.
#
#
#
# question==============================
# preference for any particular professor and why
#
# BERT ANSWER===========================
#
# OPenAI ANSWER=====================
#
# 1. I have a strong preference for Professor Z, as her work in contemporary cultural discourse in Egyptian and Islamic political movements has been hugely influential and inspiring to me. I believe that her work would be a perfect fit for my interests in artifact repatriation and reclamation of physical heritage, specifically relating to how contemporary North African political struggles utilize cultural and anthropological discourses.
#
#
#
# question==============================
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
# my mother ’ s clerking post at the American consulate in Cairo
# artifacts of a civilization that far preceded the origins of what I understood to be “ western ” civilizations
# intersection of cultural and political analysis expanded as I got older and began to unpack the complicated colonial forces that played a part in both early and contemporary Egyptology
# better support repatriation efforts
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# American University in Cairo
# capitalize on this personal experience
# independent scholarship and teaching following graduation.
#
# OPenAI ANSWER=====================
#
# 1. Addressing the gaps in scholarship in Egyptological studies by utilizing modeling techniques to support a more culturally-focused analysis of the flow of expropriation during the heyday of colonial extraction.
# 2. Serving as a paragon not only of interdisciplinarity and intellectual inventiveness to my future students, but to continue to be a productive and prominent member of the department's research cohort.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
# my mother ’ s clerking post at the American consulate in Cairo provided us with an immense array of benefits, and those that impacted me most were, unsurprisingly, the plethora of cultural institutions a short walk away from our home.
# gazing at artifacts of a civilization that far preceded the origins of what I understood to be “ western ” civilizations
# cultural and political analysis expanded as I got older and began to unpack the complicated colonial forces that played a part in both early and contemporary Egyptology
# British colonialism, and how this resulted in a still - developing tension between international exhibition and the local or indigenous preservation of civilizational artifacts.
#
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# Presidential Internship program in 2019, just after graduating. Returning to Cairo for the first time since I was 13 years old
# [CLS] previous experiences in thwe field [SEP] To this end, I propose utilizing modeling techniques common to digital - archaeological projects in Egyptological studies to support a more culturally - focused analysis of the flow of expropriation during the heyday of colonial extraction
# independent scholarship and teaching
#
# OPenAI ANSWER=====================
#
# 1. I have previous experience in the field of anthropology, specifically in the areas of historiography and political analysis.
# 2. I would seek to utilize modeling techniques common to digital-archaeological projects in Egyptological studies to support a more culturally-focused analysis of the flow of expropriation during the heyday of colonial extraction in the early 20th century.
# 3. I would seek to serve as a paragon not only of ________’s interdisciplinarity and intellectual inventiveness to my future students, but to continue to be a productive and prominent member of _____’s research cohort no matter where I end up teaching.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# [CLS] fguture contribution you want to make in the field [SEP] One of the greatest gifts my parents gave to me, very early on, was a keen sense of just how unique my childhood was. Though by no means a position of high stature, my mother ’ s clerking post at the American consulate in Cairo provided us with an immense array of benefits
# intersection of cultural and political analysis expanded as I got older and began to unpack the complicated colonial forces that played a part in both early and contemporary Egyptology. As I matured as a student, I became able to articulate questions that had hitherto lived as abstract uneasiness in my head.
# [CLS] fguture contribution you want to make in the field [SEP] As I began to ask more pointed questions, and gained the ability to explore museum records on my own
# better support repatriation efforts
# historiographic focus of my work, I ’ m keen to shift into the present politics around artifact repatriation and reclamation of physical heritage
# Presidential Internship program
# capitalize on this personal experience
# support a more culturally - focused analysis
# [CLS] fguture contribution you want to make in the field [SEP] If admitted to _ _ _ _ _ _'s graduate program, I would not only seek to contribute to the program's ongoing scholarship
#
# OPenAI ANSWER=====================
#
# ...
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
#
#
# my interest in modern Japanese literature
# University of Michigan
# University of Michigan
#
# OPenAI ANSWER=====================
#
# 1. I am committed to this intellectual journey, and to the University of Michigan itself. Though I’ve yet to meet personally with any faculty members, Christopher Hill (for modern Japanese literature) and Jennifer Robertson (for Japanese ethnography) appear to possess research interests most closely aligning with my own.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
# storytelling — my other major was English, after all — but I ’ d never considered integrating my passion for Japanese with my love of literature until my junior year of college
# crave more.
# my interest in modern Japanese literature
# English teacher. There, I plunged myself into Ainu culture : I visited several Ainu museums, conversed in Japanese with various Ainu people, and attended a weekly Ainu - language immersion class for two months ( irankarapte! ).
# they tell a story of Japan — a story I am committed to engaging with on a scholarly level. This is why I am ready for graduate school at the University of Michigan.
# For the past year I ’ ve worked as a freelance writer and editor
# University of Michigan
#
# OPenAI ANSWER=====================
#
# 1. I’ve studied Japanese literature and culture extensively, both in my undergraduate studies at Sophia University in Tokyo and during my year of teaching English in a small town in Hokkaido last year.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# English teacher
# engaging with on a scholarly
# my overarching goal is to break into Japanese - English translation, preferably in the literary sector.
#
# OPenAI ANSWER=====================
#
# 1. I want to contribute to the field of Japanese studies by deepening my understanding of the symbolism and syntax of Japanese narratives, as well as honing my Japanese-language skills.
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample1.txt
# /content/gdrive/MyDrive/FutureDataWork/sop/sop_sample/sample1analysis.txt.2
#
#
#
# question==============================
# curriculum study at this school
#
# BERT ANSWER===========================
# M. Arch degree
# designing grandiose buildings that would change a city
#
# afternoon shift there in the peak of summer
# BeMo2
# ABC College of Architecture
# Art History, African American Literature, Anthropology, and Cultures of Ancient Greece,
# New Dimensions of Architecture
# ecologically efficient and socially cohesive architectural solutions
# innovative design
# seminars and conferences that frequently feature the names of the architects at the forefront of design innovation.
# [CLS] curriculum study at this school [SEP] This education is exactly what I need to launch me into the next phase of my career, where I hope to gain experience at one of New York ’ s top green architecture firms, working on problems of low - budget housing, eco - friendly factory designs, and organic city planning. Eventually, I hope to specialize in sustainable, low - budget urban planning for socio - economically disadvantaged neighborhoods.
# a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# 1. ABC College of Architecture, New York offers a robust curriculum in engineering mechanics, surveying, soil mechanics, steel structures, model making etc. which helps students hone their technical skills and develop a deeper understanding of the socio-ecological impact of architecture.
#
#
#
# question==============================
# reasons for studying the program
#
# BERT ANSWER===========================
# a M. Arch degree “ Architecture is the will of an epoch translated into space.
# cherished romantic ideals of designing grandiose buildings that would change a city ; of adding my name to the list of architectural geniuses who had immortalized their vision of the world in concrete, steel, glass, and stone.
# women ’ s shelter
# bulldozers in the park. It was being torn up to make room for yet another building. I saw that completed building a year later – a grey block of steel that did not utilize any of the original park space
#
# robust curriculum I pursued at ABC College of Architecture, New York. I took up advanced coursework in Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which helped me hone my technical skills.
# helped me develop a deeper understanding of the socio - ecological impact of architecture and ethical responsibilities of architects
# junior year at college, I participated in the New Dimensions of Architecture conference held in New York City
# ecologically efficient and socially cohesive architectural solutions
# I would love to learn from him and collaborate with him to continue to explore my interest in these topics.
# budding green architect, nothing is more attractive than your quarterly line - up of seminars and conferences that frequently feature the names of the architects at the forefront of design innovation.
# working on problems of low - budget housing, eco - friendly factory designs, and organic city planning. Eventually, I hope to specialize in sustainable, low - budget urban planning for socio - economically disadvantaged neighborhoods.
# It was an early lesson that a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# 1.The program offers a comprehensive education in the latest architectural innovations and socio-economic evolutions in architecture.
# 2.The program provides a strong background in the technical and socio-economic aspects of architecture, which will enable me to pursue sustainable architectural solutions with greater efficacy.
# 3.The program offers opportunities to learn from and work directly with renowned architects, which will provide me with invaluable insight into the design theories of leading green architects.
#
#
#
# question==============================
# reasons for studying at this particular college/university?
#
# BERT ANSWER===========================
# sustainable architecture and believe that a M. Arch degree “ Architecture is the will of an epoch translated into space.
# romantic ideals
# [CLS] reasons for studying at this particular college / university? [SEP] One day when I was working the afternoon shift there in the peak of summer
# robust curriculum I pursued at ABC College of Architecture, New York. I took up advanced coursework in Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which helped me hone my technical skills.
# helped me develop a deeper understanding of the socio - ecological impact of architecture and ethical responsibilities of architects
# ecologically efficient and socially cohesive architectural solutions
# interest in these topics.
# budding green architect, nothing is more attractive than your quarterly line - up of seminars and conferences that frequently feature the names of the architects at the forefront of design innovation.
# what I need to launch me into the next phase of my career, where I hope to gain experience at one of New York ’ s top green architecture firms, working on problems of low - budget housing, eco - friendly factory designs, and organic city planning
# cultural power an architect can wield. It was an early lesson that a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# 1. I chose ABC College of Architecture, New York because of its robust curriculum in engineering mechanics, surveying, soil mechanics, steel structures, model making etc. which helped me hone my technical skills.
#
#
#
# question==============================
# experience you have in your field
#
# BERT ANSWER===========================
#
# cherished romantic ideals of designing grandiose buildings that would change a city ; of adding my name to the list of architectural geniuses
# [CLS] experience you have in your field [SEP] The true breakthrough for me took place in my sophomore year of college, when I was volunteering at The Bowery Mission
#
#
# Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which helped me hone my technical skills.
# Art History, African American Literature, Anthropology, and Cultures of Ancient Greece, which helped me develop a deeper understanding of the socio - ecological impact of architecture and ethical responsibilities of architects
# ecologically efficient and socially cohesive architectural solutions
# innovative design theories have a tremendous potential for sustainable architecture solutions
# budding green architect
#
# cultural power an architect can wield. It was an early lesson that a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# I have experience in the field of architecture, having completed my undergraduate studies at ABC College of Architecture, New York. I am currently pursuing my graduate degree at XYZ University, where I am studying advanced coursework in Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which has helped me hone my technical skills. My interest in sustainable architecture has developed over the years, and I am particularly interested in the social and anthropological impact of architecture. I have studied Art History, African American Literature, Anthropology, and Cultures of Ancient Greece which has helped me develop a deeper understanding of the socio-ecological impact of architecture and ethical responsibilities of architects. With this strong background of academic exploration, my architectural philosophy continues to evolve. I became interested in cutting-edge design techniques and their application to sustainable design. In my junior year at college, I participated in the New Dimensions of Architecture conference held in New York City presenting my own paper on “Analyzing the Implications of the Weiszman Design Theory for the Sustainable Architecture of the Future”. In fact, it was at this conference that I met Professor Richard Wright, the esteemed architect and professor emeritus at the Architecture department of XYZ University. Talking with him was one of the most enlightening moments of my life. We discussed our shared passion for ecologically efficient and socially cohesive architectural solutions, and he introduced me to the works of Leonard Nieman, Mary Andrews, and other cutting-edge green architecture firms that are making a real contribution to ecologically sustainable urban planning.
#
#
#
# question==============================
# preference for any particular professor and why
#
# BERT ANSWER===========================
#
# architects
# a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# 1. I have a strong preference for Professor Wright and would love to learn from him in the context of sustainable architecture. He is an innovative architect with a tremendous potential for sustainable design solutions.
#
#
#
# question==============================
# adding value to our university and our program while studying there
#
# BERT ANSWER===========================
# sustainable architecture
# designing grandiose buildings that would change a city
# The Bowery Mission
#
# ABC College of Architecture
# Art History, African American Literature, Anthropology, and Cultures of Ancient Greece, which helped me develop a deeper understanding of the socio - ecological impact of architecture and ethical responsibilities of architects
# [CLS] adding value to our university and our program while studying there [SEP] In my junior year at college, I participated in the New Dimensions of Architecture conference held in New York City
# innovative design theories have a tremendous potential for sustainable architecture
# budding green architect
# top green architecture firms
# inspired in me an awe for the cultural power an architect can wield.
#
# OPenAI ANSWER=====================
#
# 1.I am passionate about sustainable architecture and believe that a M.Arch degree will add value to our university and our program while studying there.
#
#
#
# question==============================
# previous experiences in thwe field
#
# BERT ANSWER===========================
# sustainable architecture
# architectural geniuses who had immortalized their vision of the world in concrete, steel, glass, and stone
#
#
# BeMo2
# Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making
#
# ecologically efficient and socially cohesive architectural solutions
# budding green architect
# green architecture firms
# teenage years
#
# OPenAI ANSWER=====================
#
# 1. I have previous experience in the field of architecture, having completed undergraduate studies in architecture at ABC College of Architecture, New York. During my undergraduate studies, I took up advanced coursework in Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc., which helped me hone my technical skills and develop a deeper understanding of the socio-ecological impact of architecture. My architectural philosophy continued to evolve as I became interested in cutting-edge design techniques and their application to sustainable design. In my junior year at college, I participated in the New Dimensions of Architecture conference held in New York City, presenting my own paper on “Analyzing the Implications of the Weiszman Design Theory for the Sustainable Architecture of the Future”. This conference was an important moment in my career as it introduced me to the works of Leonard Nieman, Mary Andrews, and other green architecture firms that are making a real contribution to ecologically sustainable urban planning.
#
#
#
# question==============================
# fguture contribution you want to make in the field
#
# BERT ANSWER===========================
# [CLS] fguture contribution you want to make in the field [SEP] I am passionate about sustainable architecture
# designing grandiose buildings that would change a city ; of adding my name to the list of architectural geniuses who had immortalized their vision of the world in concrete, steel, glass, and stone.
# BeMo2
# Engineering Mechanics, Surveying, Soil Mechanics, Steel Structures, Model Making etc. which helped me hone my technical skills.
# architects
#
# I would love to learn from him and collaborate with him to continue to explore my interest in these topics.
# budding green architect, nothing is more attractive than your quarterly line - up of seminars and conferences that frequently feature the names of the architects at the forefront of design innovation.
# what I need to launch me into the next phase of my career, where I hope to gain experience at one of New York ’ s top green architecture firms, working on problems of low - budget housing, eco - friendly factory designs, and organic city planning
# cultural power an architect can wield. It was an early lesson that a building can both represent and transform spaces.
#
# OPenAI ANSWER=====================
#
# I want to make a significant contribution to the field of sustainable architecture, by helping to develop innovative and ecologically sustainable design solutions for urban planning and community development. My academic background in engineering mechanics, surveying, soil mechanics, steel structures, and model making will help me to develop the technical skills necessary to create innovative and sustainable designs. My passion for sustainable design and my understanding of the social and ecological impact of architecture will help me to develop innovative and ecologically sound solutions that meet the needs of both the client and the environment. I am excited to learn from and work with Professor Wright, one of the leading architects in the field of sustainable design, and to contribute my skills and knowledge to the development of ecologically sustainable urban planning solutions.
